# %%
! pip install numpy
! pip install matplotlib
! pip install seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (1.24.4)
# Requirement already satisfied: matplotlib in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.20 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from seaborn) (1.24.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from seaborn) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\rager\desktop\programming\minor project\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
import os
file_path = os.path.join(os.getcwd(),"data","Fertilizer Prediction.csv")
df = pd.read_csv(file_path)
df.head()
# Out:
#    Temparature  Humidity   Moisture Soil Type  Crop Type  Nitrogen  Potassium  \
# 0           26         52        38     Sandy      Maize        37          0
# 1           29         52        45     Loamy  Sugarcane        12          0
# 2           34         65        62     Black     Cotton         7          9
# 3           32         62        34       Red    Tobacco        22          0
# 4           28         54        46    Clayey      Paddy        35          0
#
#    Phosphorous Fertilizer Name
# 0            0            Urea
# 1           36             DAP
# 2           30        14-35-14
# 3           20           28-28
# 4            0            Urea

# %%
df.describe()
# Out:
#        Temparature  Humidity    Moisture   Nitrogen  Potassium  Phosphorous
# count    99.000000  99.000000  99.000000  99.000000  99.000000    99.000000
# mean     30.282828  59.151515  43.181818  18.909091   3.383838    18.606061
# std       3.502304   5.840331  11.271568  11.599693   5.814667    13.476978
# min      25.000000  50.000000  25.000000   4.000000   0.000000     0.000000
# 25%      28.000000  54.000000  34.000000  10.000000   0.000000     9.000000
# 50%      30.000000  60.000000  41.000000  13.000000   0.000000    19.000000
# 75%      33.000000  64.000000  50.500000  24.000000   7.500000    30.000000
# max      38.000000  72.000000  65.000000  42.000000  19.000000    42.000000

# %%
df.shape
# Out:
# (99, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Temparature      99 non-null     int64
#  1   Humidity         99 non-null     int64
#  2   Moisture         99 non-null     int64
#  3   Soil Type        99 non-null     object
#  4   Crop Type        99 non-null     object
#  5   Nitrogen         99 non-null     int64
#  6   Potassium        99 non-null     int64
#  7   Phosphorous      99 non-null     int64
#  8   Fertilizer Name  99 non-null     object
# dtypes: int64(6), object(3)
# memory usage: 7.1+ KB

# %%
df.isnull().sum()
# Out:
# Temparature        0
# Humidity           0
# Moisture           0
# Soil Type          0
# Crop Type          0
# Nitrogen           0
# Potassium          0
# Phosphorous        0
# Fertilizer Name    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# Length: 99, dtype: bool

# %%
Columns = list(df.columns)
Columns
# Out:
# ['Temparature',
#  'Humidity ',
#  'Moisture',
#  'Soil Type',
#  'Crop Type',
#  'Nitrogen',
#  'Potassium',
#  'Phosphorous',
#  'Fertilizer Name']

# %%
num_cols = [col for col in Columns if df[col].dtype != 'O']
cat_cols = [col for col in Columns if df[col].dtype == "O"]
num_cols, cat_cols
# Out:
# (['Temparature',
#   'Humidity ',
#   'Moisture',
#   'Nitrogen',
#   'Potassium',
#   'Phosphorous'],
#  ['Soil Type', 'Crop Type', 'Fertilizer Name'])

# %%
df[num_cols].head()
# Out:
#    Temparature  Humidity   Moisture  Nitrogen  Potassium  Phosphorous
# 0           26         52        38        37          0            0
# 1           29         52        45        12          0           36
# 2           34         65        62         7          9           30
# 3           32         62        34        22          0           20
# 4           28         54        46        35          0            0

# %%
sns.heatmap(df[num_cols].corr(method = 'pearson'),annot = True)
# Out:
# <Axes: >

# %%
for i in num_cols:
    plt.xlabel("Fertilizer")
    plt.ylabel(i)
    sns.barplot(x = df['Fertilizer Name'],y = df[i])
    plt.show()

# %%
sns.countplot(x = df['Fertilizer Name'],hue = df['Soil Type'],color='green')
plt.show()

# %%
for i in num_cols:
    plt.figure(figsize=(4,4))
    plt.xlabel(i)
    plt.ylabel("Density")
    sns.boxplot(df[i])
    plt.show()
